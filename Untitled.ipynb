# %%
import numpy as np
import matplotlib.pyplot as plt
from pyomo.environ import *
import pandas as pd
from scipy.stats import truncnorm

# %%
np.random.seed(0)
def get_surgery_time(mean,std):
    return truncnorm.rvs(-1,1,loc=mean,scale=std)

# %%
def get_plot(avg_model,dummy_block_len,n_surgeries):
    colors = ['orange','pink','cyan','lightgreen','peachpuff','gold']
    plt.figure(figsize=(10,6))
    j = 0
    gastro_y = [1,1,1,2,2,2,2]
    gastro_x = [1,2,3,3,4,5,6]
    card_y = [3,9,3,3,9,1]
    card_x = [1,1,3,5,5,6]
    gyn_y = [6,6,7,6,7,6,7,7,3]
    gyn_x = [1,2,2,3,3,4,4,5,6]
    med_y = [5,4]
    med_x = [3,6]
    ortho_y = [4,4,5,10,4,4,5]
    ortho_x = [1,2,2,3,4,5,6]
    uro_y = [8,10,8,9,8,8,6]
    uro_x = [1,1,2,3,4,5,6]

    specs = ['CARD','GASTRO','GYN','MED','ORTHO','URO']
    surgery_data = {'CARD':[99.0,53.0],'GASTRO':[132.0,76.0],'GYN':[78.0,52.0],'MED':[75.0,32.0],'ORTHO':[142.0,58.0],'URO':[72.0,38.0]}
    blocks = {'CARD':[2,6,16,28,32,33],'GASTRO':[1,8,14,15,22,27,34],'GYN':[4,11,12,18,19,24,25,30,35],'MED':[17,36],'ORTHO':[3,9,10,21,23,29,37],'URO':[5,7,13,20,26,31,38]}
    block_len = [8*60.0 for i in range(32)]+[dummy_block_len*60.0 for i in range(len(specs))]
    n_blocks = len(block_len)
    percent_surg = {'CARD':14,'GASTRO':18,'GYN':28,'MED':5,'ORTHO':17,'URO':18}
    barh_blocks = {'GASTRO':[gastro_y,gastro_x],'CARD':[card_y,card_x],'GYN':[gyn_y,gyn_x],'MED':[med_y,med_x],'ORTHO':[ortho_y,ortho_x],'URO':[uro_y,uro_x]}
    barh_colors = {}
    
    for i in range(len(specs)):
        barh_colors[specs[i]] = colors[i]

    fig,ax = plt.subplots(figsize=(15,12))
    j,k = 0,0
    for i in specs:
        for m in range(len(blocks[i])):
            text =int(np.round(sum(avg_model.y[idx+1,blocks[i][m]].value for idx in range(n_surgeries))))
            ax.barh(y=11-barh_blocks[i][0][m],width=0.8,height=0.6,left=barh_blocks[i][1][m]-0.4,align='center',color=barh_colors[i],label=i)
            ax.text(barh_blocks[i][1][m], 11-barh_blocks[i][0][m]-0.02, text, color = 'black', ha = 'left', va = 'center',size=16)
        j += 1
    #ax.set_yticks([i for i in range(11)],[' ']+['OR '+str(10-i) for i in range(10)])
    ax.set_xticks([1,2,3,4,5,6]) # values
    ax.set_xticklabels(['Monday','Tuesday','Wednesday','Thursday','Friday','Dummy'],size=15)
    ax.set_yticks([i for i in range(1,11)])
    ax.set_yticklabels(['OR '+str(10-i) for i in range(10)],size=15)


    handles, labels = plt.gca().get_legend_handles_labels()
    by_label = dict(zip(labels, handles))
    plt.legend(by_label.values(), by_label.keys())
    plt.show()

# %%
def solveProblem(n_surgeries,dummy_block_len,n_scenarios,T,with_cond=0):
    #problem parameters
    specs = ['CARD','GASTRO','GYN','MED','ORTHO','URO']
    surgery_data = {'CARD':[99.0,53.0],'GASTRO':[132.0,76.0],'GYN':[78.0,52.0],'MED':[75.0,32.0],'ORTHO':[142.0,58.0],'URO':[72.0,38.0]}
    blocks = {'CARD':[2,6,16,28,32,33],'GASTRO':[1,8,14,15,22,27,34],'GYN':[4,11,12,18,19,24,25,30,35],'MED':[17,36],'ORTHO':[3,9,10,21,23,29,37],'URO':[5,7,13,20,26,31,38]}
    block_len = [8*60.0 for i in range(32)]+[dummy_block_len*60.0 for i in range(len(specs))]
    n_blocks = len(block_len)
    percent_surg = {'CARD':14,'GASTRO':18,'GYN':28,'MED':5,'ORTHO':17,'URO':18}
    surgeries = {}
    tot = 0
    for i in specs[:len(specs)-1]:
        surgeries[i] = round(n_surgeries*percent_surg[i]/100.0)
        tot += surgeries[i]
    surgeries[specs[-1]] = n_surgeries-tot
    surgery_nums = {}
    t = 0
    for s in specs:
        surgery_nums[s] = [t,t+surgeries[s]-1]
        t = t+surgeries[s]
    
    np.random.seed(0)
    cib = np.array([[0.0 for _ in range(n_blocks)] for _ in range(n_surgeries)]) # block costs
    for s in specs:
        for i in range(surgery_nums[s][0],surgery_nums[s][1]+1):
            #costs = sorted([np.random.randint(low=1,high=5)*100 for _ in range(len(blocks[s])-1)])
            costs = [np.random.randint(low=1,high=5)*100 for _ in range(len(blocks[s])-1)]
            f = 0
            for b in blocks[s][:len(blocks[s])-1]:
                cib[i,b-1] = costs[f]
                f += 1
    dummy_cost = 1000
    for s in specs:
        for i in range(surgery_nums[s][0],surgery_nums[s][1]+1):
            b = blocks[s][-1]
            cib[i,b-1] = dummy_cost
    cob = np.array([5.0 for _ in range(n_blocks)])
    cgb = np.array([5.0/1.5 for _ in range(n_blocks-len(specs))]+[0.0 for _ in range(len(specs))])
    
    p = [[0.0 for _ in range(n_blocks)] for _ in range(n_surgeries)]
    p = np.array(p)
    t = 0
    for s in specs:
        for i in range(surgeries[s]):
            for b in blocks[s]:
                p[t,b-1] = 1.0
            t += 1
            
    avg_model = ConcreteModel()
    avg_model.y = Var(RangeSet(n_surgeries),RangeSet(n_blocks),domain=Binary)
    avg_model.o = Var(RangeSet(n_blocks),RangeSet(n_scenarios),domain=NonNegativeReals,bounds=(0,120))
    avg_model.g = Var(RangeSet(n_blocks),RangeSet(n_scenarios),domain=NonNegativeReals)

    avg_model.atmost1 = ConstraintList()
    for i in range(n_surgeries):
        avg_model.atmost1.add(expr=sum(avg_model.y[i+1,b] for b in range(1,n_blocks+1))==1)

    avg_model.specfeas = ConstraintList()
    for i in range(n_surgeries):
        for b in range(n_blocks):
            avg_model.specfeas.add(expr=avg_model.y[i+1,b+1] <= p[i,b])

    avg_model.ogcons = ConstraintList()
    for n in range(n_scenarios):
        t = 0
        for s in specs:
            for b in blocks[s]:
                avg_model.ogcons.add(expr=avg_model.o[b,n+1]-avg_model.g[b,n+1] == sum(get_surgery_time(surgery_data[s][0],surgery_data[s][1])*avg_model.y[i+1,b] for i in range(surgery_nums[s][0],surgery_nums[s][1]+1))-block_len[b-1])
    if with_cond == 1:
        avg_model.atleast1inblock = ConstraintList()
        for b in range(n_blocks-len(specs)):
            avg_model.atleast1inblock.add(expr=sum(avg_model.y[i+1,b+1] for i in range(n_surgeries))>=1.0)

    avg_model.cost = Objective(expr=sum(sum(avg_model.y[i+1,b+1]*cib[i,b] for i in range(n_surgeries)) for b in range(n_blocks))+(sum(cob[b]*avg_model.o[b+1,n+1]+cgb[b]*avg_model.g[b+1,n+1] for b in range(n_blocks) for n in range(n_scenarios)))/n_scenarios,sense=minimize)
    
    opt = SolverFactory('cplex')
    opt.options['timelimit'] = T
    print("Solving for Surgeries =",n_surgeries,', scenarios =',n_scenarios)
    result = opt.solve(avg_model,tee=True)
    print("  Solver status :",result.solver.status)
    print("  Solver Termination condition :", result.solver.termination_condition)
    
    assignments = np.array([[0.0 for _ in range(n_blocks)] for _ in range(n_surgeries)])
    for i in range(n_surgeries):
        for b in range(n_blocks):
            assignments[i,b] = avg_model.y[i+1,b+1].value
    
    get_plot(avg_model,dummy_block_len,n_surgeries)
    
    return

# %%
'''
surgs = [100,125]
scenarios = [1000,1500]
T = 1800
for s in surgs:
    for n in scenarios:
        solveProblem(s,100,n,T,with_cond=0)
'''
# Out:
# '\nsurgs = [100,125]\nscenarios = [1000,1500]\nT = 1800\nfor s in surgs:\n    for n in scenarios:\n        solveProblem(s,100,n,T,with_cond=0)\n'

# %%
surgs = [100,125]
scenarios = [1000,1500]
T = 1800
for s in surgs:
    for n in scenarios:
        solveProblem(s,100,n,T,with_cond=1)
# Out:
# Solving for Surgeries = 100 , scenarios = 1000
#
# Welcome to IBM(R) ILOG(R) CPLEX(R) Interactive Optimizer 20.1.0.0
#   with Simplex, Mixed Integer & Barrier Optimizers
# 5725-A06 5725-A29 5724-Y48 5724-Y49 5724-Y54 5724-Y55 5655-Y21
# Copyright IBM Corp. 1988, 2020.  All Rights Reserved.
#
# Type 'help' for a list of available commands.
# Type 'help' followed by a command name for more
# information on commands.
#
# CPLEX> Logfile 'cplex.log' closed.
# Logfile 'C:\Users\91824\AppData\Local\Temp\tmpfbpzbj_r.cplex.log' open.
# CPLEX> New value for time limit in seconds: 1800
# CPLEX> Problem 'C:\Users\91824\AppData\Local\Temp\tmppyox0qd2.pyomo.lp' read.
# Read time = 0.56 sec. (14.83 ticks)
# CPLEX> Problem name         : C:\Users\91824\AppData\Local\Temp\tmppyox0qd2.pyomo.lp
# Objective sense      : Minimize
# Variables            :   79801  [Nneg: 38001,  Box: 38000,  Binary: 3800]
# Objective nonzeros   :   70717
# Linear constraints   :   41933  [Less: 3800,  Greater: 32,  Equal: 38101]
#   Nonzeros           :  803801
#   RHS nonzeros       :   38850
#
# Variables            : Min LB: 0.000000         Max UB: 120.0000
# Objective nonzeros   : Min   : 0.003333333      Max   : 1000.000
# Linear constraints   :
#   Nonzeros           : Min   : 1.000000         Max   : 207.9979
#   RHS nonzeros       : Min   : 1.000000         Max   : 6000.000
# CPLEX> Version identifier: 20.1.0.0 | 2020-11-10 | 9bedb6d68
# CPXPARAM_TimeLimit                               1800
# Tried aggregator 2 times.
# MIP Presolve eliminated 10799 rows and 17080 columns.
# Aggregator did 5 substitutions.
# Reduced MIP has 31129 rows, 62716 columns, and 675338 nonzeros.
# Reduced MIP has 712 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.72 sec. (320.09 ticks)
# Probing time = 0.25 sec. (32.86 ticks)
# Cover probing fixed 0 vars, tightened 23002 bounds.
# Tried aggregator 1 time.
# Detecting symmetries...
# MIP Presolve eliminated
# Elapsed time = 139.45 sec. (33052.50 ticks, tree = 9.70 MB, solutions = 11)
#     490   264    30891.0730    41    30960.2807    30884.6717   239780    0.24%
#     534   279        cutoff          30960.2807    30888.5541   260137    0.23%
#     583   295    30907.9895    50    30960.2807    30890.0745   276331    0.23%
#     626   291    30929.8990    43    30960.2807    30893.4262   274216    0.22%
#     673   307    30923.2312    33    30960.2807    30893.7873   286397    0.21%
# *   706+  324                        30960.0511    30894.3867             0.21%
#     718   332        cutoff          30960.0511    30896.4209   320510    0.21%
#     758   339    30949.2689    44    30960.0511    30898.9905   333708    0.20%
#     801   346        cutoff          30960.0511    30899.1770   344715    0.20%
#     842   348    30957.8093    38    30960.0511    30899.8481   346745    0.19%
#     875   349    30936.2223    36    30960.0511    30900.6645   353959    0.19%
# Elapsed time = 191.50 sec. (42896.04 ticks, tree = 19.98 MB, solutions = 12)
#     902   354    30949.0145    28    30960.0511    30902.8501   367688    0.18%
#     937   358        cutoff          30960.0511    30904.5722   382216    0.18%
#     966   370    30954.3971    44    30960.0511    30907.2720   413883    0.17%
# *   985+  375                        30959.6674    30907.2720             0.17%
#    1004   381        cutoff          30959.6674    30907.2720   438378    0.17%
# *  1040   381      integral     0    30956.9435    30908.7844   436815    0.16%
#    1060   376    30939.6513    46    30956.9435    30908.7844   420707    0.16%
#    1099   382        cutoff          30956.9435    30908.7844   442932    0.16%
# *  1125+  372                        30951.2572    30912.3106             0.13%
#    1146   379        cutoff          30951.2572    30913.1995   471617    0.12%
#    1187   378        cutoff          30951.2572    30913.8815   473872    0.12%
#    1227   350        cutoff          30951.2572    30914.2262   493705    0.12%
#    1276   339        cutoff          30951.2572    30916.6904   525248    0.11%
# Elapsed time = 241.34 sec. (52644.74 ticks, tree = 19.38 MB, solutions = 15)
#    1324   335    30950.6822    33    30951.2572    30917.1992   539337    0.11%
#    1379   331    30943.7582    14    30951.2572    30921.7493   553887    0.10%
#    1443   317        cutoff          30951.2572    30922.3147   580086    0.09%
#    1512   297    30942.3161    34    30951.2572    30926.5142   594446    0.08%
#    1580   257        cutoff          30951.2572    30928.2329   613288    0.07%
#    1657   225        cutoff          30951.2572    30932.8725   629033    0.06%
#    1745   170        cutoff          30951.2572    30936.3848   643173    0.05%
#    1847    69        cutoff          30951.2572    30942.4878   656859    0.03%
#
# Cover cuts applied:  11
# Flow cuts applied:  1209
# Mixed integer rounding cuts applied:  3761
# Lift and project cuts applied:  9
# Gomory fractional cuts applied:  7
#
# Root node processing (before b&c):
#   Real time             =   58.55 sec. (19479.78 ticks)
# Parallel b&c, 8 threads:
#   Real time             =  224.95 sec. (41695.89 ticks)
#   Sync time (average)   =   30.84 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =  283.50 sec. (61175.67 ticks)
#
# Solution pool: 15 solutions saved.
#
# MIP - Integer optimal, tolerance (0.0001/1e-06):  Objective =  3.0951257159e+04
# Current MIP best bound =  3.0948376372e+04 (gap = 2.88079, 0.01%)
# Solution time =  283.50 sec.  Iterations = 661075  Nodes = 1873 (23)
# Deterministic time = 61175.90 ticks  (215.79 ticks/sec)
#
# CPLEX> Incumbent solution written to file 'C:\Users\91824\AppData\Local\Temp\tmprk452m0g.cplex.sol'.
# CPLEX>   Solver status : ok
#   Solver Termination condition : optimal
# Solving for Surgeries = 100 , scenarios = 1500
#
# Welcome to IBM(R) ILOG(R) CPLEX(R) Interactive Optimizer 20.1.0.0
#   with Simplex, Mixed Integer & Barrier Optimizers
# 5725-A06 5725-A29 5724-Y48 5724-Y49 5724-Y54 5724-Y55 5655-Y21
# Copyright IBM Corp. 1988, 2020.  All Rights Reserved.
#
# Type 'help' for a list of available commands.
# Type 'help' followed by a command name for more
# information on commands.
#
# CPLEX> Logfile 'cplex.log' closed.
# Logfile 'C:\Users\91824\AppData\Local\Temp\tmpy_z6gt60.cplex.log' open.
# CPLEX> New value for time limit in seconds: 1800
# CPLEX> Problem 'C:\Users\91824\AppData\Local\Temp\tmpoplloraq.pyomo.lp' read.
# Read time = 0.81 sec. (21.82 ticks)
# CPLEX> Problem name         : C:\Users\91824\AppData\Local\Temp\tmpoplloraq.pyomo.lp
# Objective sense      : Minimize
# Variables            :  117801  [Nneg: 57001,  Box: 57000,  Binary: 3800]
# Objective nonzeros   :  105717
# Linear constraints   :   60933  [Less: 3800,  Greater: 32,  Equal: 57101]
#   Nonzeros           : 1200301
#   RHS nonzeros       :   57850
#
# Variables            : Min LB: 0.000000         Max UB: 120.0000
# Objective nonzeros   : Min   : 0.002222222      Max   : 1000.000
# Linear constraints   :
#   Nonzeros           : Min   : 1.000000         Max   : 207.9979
#   RHS nonzeros       : Min   : 1.000000         Max   : 6000.000
# CPLEX> Version identifier: 20.1.0.0 | 2020-11-10 | 9bedb6d68
# CPXPARAM_TimeLimit                               1800
# Tried aggregator 2 times.
# MIP Presolve eliminated 14299 rows and 24080 columns.
# Aggregator did 5 substitutions.
# Reduced MIP has 46629 rows, 93716 columns, and 1012338 nonzeros.
# Reduced MIP has 712 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 1.06 sec. (474.03 ticks)
# Probing time = 0.81 sec. (47.94 ticks)
# Cover probing fixed 0 vars, tightened 34502 bounds.
# Tried aggregator 1 time.
# Detecting symmetries...
# MIP Presolve eliminated 3 rows and 9 columns.
# Reduced MIP has 46626 rows, 93707 columns, and 1012319 nonzeros.
# Reduced MIP has 707 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 1.78 sec. (539.39 ticks)
# Probing time = 0.41 sec. (45.73 ticks)
# Clique table members: 95.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 8 threads.
# Root relaxation solution time = 53.75 sec. (9919.70 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                        77191.6524     1750.6127            97.73%
# *     0+    0                        45889.1524     1750.6127            96.19%
#       0     0    30674.2260    57    45889.1524    30674.2260    13777   33.16%
# *     0+    0                        31322.2075    30674.2260             2.07%
#       0     0    30835.1022    63    31322.2075    Cuts: 4266    17822    1.56%
# *     0+    0                        31134.7196    30835.1022             0.96%
#       0     0    30857.5486    66    31134.7196    Cuts: 1463    19676    0.89%
#       0     0    30865.3771    67    31134.7196     Cuts: 647    20763    0.87%
#       0     0    30869.4216    65    31134.7196     Cuts: 363    21542    0.85%
#       0     0    30871.9531    66    31134.7196     Cuts: 369    22109    0.84%
# Detecting symmetries...
#       0     0    30874.1125    67    31134.7196     Cuts: 256    22575    0.84%
#       0     0    30875.2551    62    31134.7196     Cuts: 191    22948    0.83%
#       0     0    30876.1812    65    31134.7196     Cuts: 128    23192    0.83%
# *     0+    0                        31089.2046    30876.1812             0.69%
# *     0+    0                        31000.1751    30876.1812             0.40%
# Detecting symmetries...
#       0     2    30876.1812    65    31000.1751    30876.1812    23192    0.40%
# Elapsed time = 105.63 sec. (36869.12 ticks, tree = 0.02 MB, solutions = 6)
#       1     3    30879.7597    65    31000.1751    30876.1829    23646    0.40%
# Elapsed time = 311.88 sec. (70752.83 ticks, tree = 30.42 MB, solutions = 11)
#     759   234    30975.0685    47    30977.1580    30941.3787   391227    0.12%
#     787   227        cutoff          30977.1580    30942.1053   400958    0.11%
#     810   231        cutoff          30977.1580    30942.8438   390242    0.11%
#     836   227        cutoff          30977.1580    30943.4503   403922    0.11%
#     860   219    30973.9111    45    30977.1580    30943.4653   420884    0.11%
#     886   204        cutoff          30977.1580    30946.4437   442533    0.10%
#     907   203    30975.9154    41    30977.1580    30946.4437   444126    0.10%
#     934   174    30961.5451    49    30977.1580    30948.3980   480005    0.09%
#     955   159        cutoff          30977.1580    30948.9897   489715    0.09%
#     975   173        cutoff          30977.1580    30950.3128   479427    0.09%
# Elapsed time = 369.00 sec. (80537.78 ticks, tree = 21.64 MB, solutions = 11)
#    1007   153    30976.5153    18    30977.1580    30952.5673   499344    0.08%
#    1045   135        cutoff          30977.1580    30954.6104   512824    0.07%
#    1079   113        cutoff          30977.1580    30958.7791   526690    0.06%
#    1132   106        cutoff          30977.1580    30960.9606   531100    0.05%
#    1208    48    30974.5313    30    30977.1580    30966.7295   556887    0.03%
#
# Cover cuts applied:  20
# Flow cuts applied:  1697
# Mixed integer rounding cuts applied:  4917
# Lift and project cuts applied:  9
# Gomory fractional cuts applied:  11
#
# Root node processing (before b&c):
#   Real time             =  104.91 sec. (36691.25 ticks)
# Parallel b&c, 8 threads:
#   Real time             =  295.34 sec. (49155.16 ticks)
#   Sync time (average)   =   43.89 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) =  400.25 sec. (85846.41 ticks)
#
# Solution pool: 11 solutions saved.
#
# MIP - Integer optimal, tolerance (0.0001/1e-06):  Objective =  3.0977157965e+04
# Current MIP best bound =  3.0974606520e+04 (gap = 2.55144, 0.01%)
# Solution time =  400.25 sec.  Iterations = 564740  Nodes = 1214 (32)
# Deterministic time = 85846.75 ticks  (214.48 ticks/sec)
#
# CPLEX> Incumbent solution written to file 'C:\Users\91824\AppData\Local\Temp\tmpop7oxjet.cplex.sol'.
# CPLEX>   Solver status : ok
#   Solver Termination condition : optimal
# Solving for Surgeries = 125 , scenarios = 1000
#
# Welcome to IBM(R) ILOG(R) CPLEX(R) Interactive Optimizer 20.1.0.0
#   with Simplex, Mixed Integer & Barrier Optimizers
# 5725-A06 5725-A29 5724-Y48 5724-Y49 5724-Y54 5724-Y55 5655-Y21
# Copyright IBM Corp. 1988, 2020.  All Rights Reserved.
#
# Type 'help' for a list of available commands.
# Type 'help' followed by a command name for more
# information on commands.
#
# CPLEX> Logfile 'cplex.log' closed.
# Logfile 'C:\Users\91824\AppData\Local\Temp\tmpvzchhpya.cplex.log' open.
# CPLEX> New value for time limit in seconds: 1800
# CPLEX> Problem 'C:\Users\91824\AppData\Local\Temp\tmpevotetr8.pyomo.lp' read.
# Read time = 0.42 sec. (17.37 ticks)
# CPLEX> Problem name         : C:\Users\91824\AppData\Local\Temp\tmpevotetr8.pyomo.lp
# Objective sense      : Minimize
# Variables            :   80751  [Nneg: 38001,  Box: 38000,  Binary: 4750]
# Objective nonzeros   :   70897
# Linear constraints   :   42908  [Less: 4750,  Greater: 32,  Equal: 38126]
#   Nonzeros           :  986501
#   RHS nonzeros       :   39055
#
# Variables            : Min LB: 0.000000         Max UB: 120.0000
# Objective nonzeros   : Min   : 0.003333333      Max   : 1000.000
# Linear constraints   :
#   Nonzeros           : Min   : 1.000000         Max   : 207.9988
#   RHS nonzeros       : Min   : 1.000000         Max   : 6000.000
# CPLEX> Version identifier: 20.1.0.0 | 2020-11-10 | 9bedb6d68
# CPXPARAM
#
# Welcome to IBM(R) ILOG(R) CPLEX(R) Interactive Optimizer 20.1.0.0
#   with Simplex, Mixed Integer & Barrier Optimizers
# 5725-A06 5725-A29 5724-Y48 5724-Y49 5724-Y54 5724-Y55 5655-Y21
# Copyright IBM Corp. 1988, 2020.  All Rights Reserved.
#
# Type 'help' for a list of available commands.
# Type 'help' followed by a command name for more
# information on commands.
#
# CPLEX> Logfile 'cplex.log' closed.
# Logfile 'C:\Users\91824\AppData\Local\Temp\tmphdb9byqs.cplex.log' open.
# CPLEX> New value for time limit in seconds: 1800
# CPLEX> Problem 'C:\Users\91824\AppData\Local\Temp\tmpogozo591.pyomo.lp' read.
# Read time = 0.45 sec. (17.37 ticks)
# CPLEX> Problem name         : C:\Users\91824\AppData\Local\Temp\tmpogozo591.pyomo.lp
# Objective sense      : Minimize
# Variables            :   80751  [Nneg: 38001,  Box: 38000,  Binary: 4750]
# Objective nonzeros   :   70897
# Linear constraints   :   42908  [Less: 4750,  Greater: 32,  Equal: 38126]
#   Nonzeros           :  986501
#   RHS nonzeros       :   39055
#
# Variables            : Min LB: 0.000000         Max UB: 120.0000
# Objective nonzeros   : Min   : 0.003333333      Max   : 1000.000
# Linear constraints   :
#   Nonzeros           : Min   : 1.000000         Max   : 207.9988
#   RHS nonzeros       : Min   : 1.000000         Max   : 6000.000
# CPLEX> Version identifier: 20.1.0.0 | 2020-11-10 | 9bedb6d68
# CPXPARAM_TimeLimit                               1800
# Tried aggregator 2 times.
# MIP Presolve eliminated 11511 rows and 17374 columns.
# Aggregator did 6 substitutions.
# Reduced MIP has 31391 rows, 63371 columns, and 831577 nonzeros.
# Reduced MIP has 891 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.58 sec. (382.23 ticks)
# Probing time = 0.20 sec. (33.33 ticks)
# Cover probing fixed 0 vars, tightened 23123 bounds.
# Tried aggregator 1 time.
# Detecting symmetries...
# MIP Presolve eliminated 241 rows and 486 columns.
# Reduced MIP has 31150 rows, 62885 columns, and 829651 nonzeros.
# Reduced MIP has 885 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.97 sec. (434.71 ticks)
# Probing time = 0.17 sec. (31.55 ticks)
# Clique table members: 119.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 8 threads.
# Root relaxation solution time = 45.33 sec. (17734.99 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                        50844.9345     1447.0764            97.15%
#       0     0    28395.7291   195    50844.9345    28395.7291    61398   44.15%
# *     0+    0                        35611.5463    28395.7291            20.26%
#       0     0    28954.9369   229    35611.5463    Cuts: 1806    66308   18.69%
#       0     0    29044.8615   246    35611.5463     Cuts: 468    69366   18.44%
# *     0+    0                        35502.5309    29044.8615            18.19%
# *     0+    0                        34998.5136    29044.8615            17.01%
#       0     0    29093.8641   252    34998.5136     Cuts: 402    72343   16.87%
#       0     0    29121.3967   256    34998.5136     Cuts: 303    74472   16.79%
#       0     0    29131.4787   253    34998.5136     Cuts: 127    75935   16.76%
# Detecting symmetries...
#       0     0    29139.2964   258    34998.5136     Cuts: 171    77084   16.74%
#       0     0    29143.2711   259    34998.5136      Cuts: 79    78092   16.73%
#       0     0    29151.4386   257    34998.5136     Cuts: 101    79146   16.71%
#       0     0    29152.3189   259    34998.5136      Cuts: 52    79424   16.70%
#       0     0    29156.1557   254    34998.5136      Cuts: 68    80178   16.69%
#       0     0    29156.7953   254    34998.5136      Cuts: 37    80321   16.69%
# Heuristic still looking.
#    3715  1778    34265.8483   126    34674.0579    29448.6887  2735531   15.07%
# Elapsed time = 1792.13 sec. (431322.14 ticks, tree = 393.65 MB, solutions = 21)
#
# Cover cuts applied:  248
# Flow cuts applied:  216
# Mixed integer rounding cuts applied:  938
# Lift and project cuts applied:  108
# Gomory fractional cuts applied:  6
#
# Root node processing (before b&c):
#   Real time             =  115.72 sec. (65681.46 ticks)
# Parallel b&c, 8 threads:
#   Real time             = 1684.61 sec. (369117.04 ticks)
#   Sync time (average)   =  167.69 sec.
#   Wait time (average)   =    0.09 sec.
#                           ------------
# Total (root+branch&cut) = 1800.33 sec. (434798.50 ticks)
#
# Solution pool: 21 solutions saved.
#
# MIP - Time limit exceeded, integer feasible:  Objective =  3.4674057855e+04
# Current MIP best bound =  2.9448688737e+04 (gap = 5225.37, 15.07%)
# Solution time = 1800.33 sec.  Iterations = 2851493  Nodes = 3762 (1958)
# Deterministic time = 434798.73 ticks  (241.51 ticks/sec)
#
# CPLEX> Incumbent solution written to file 'C:\Users\91824\AppData\Local\Temp\tmpju5s9uvp.cplex.sol'.
# CPLEX>   Solver status : ok
#   Solver Termination condition : maxTimeLimit
# Solving for Surgeries = 125 , scenarios = 1500
#
# Welcome to IBM(R) ILOG(R) CPLEX(R) Interactive Optimizer 20.1.0.0
#   with Simplex, Mixed Integer & Barrier Optimizers
# 5725-A06 5725-A29 5724-Y48 5724-Y49 5724-Y54 5724-Y55 5655-Y21
# Copyright IBM Corp. 1988, 2020.  All Rights Reserved.
#
# Type 'help' for a list of available commands.
# Type 'help' followed by a command name for more
# information on commands.
#
# CPLEX> Logfile 'cplex.log' closed.
# Logfile 'C:\Users\91824\AppData\Local\Temp\tmpsepvxgja.cplex.log' open.
# CPLEX> New value for time limit in seconds: 1800
# CPLEX> Problem 'C:\Users\91824\AppData\Local\Temp\tmp89lh0qdh.pyomo.lp' read.
# Read time = 0.66 sec. (25.75 ticks)
# CPLEX> Problem name         : C:\Users\91824\AppData\Local\Temp\tmp89lh0qdh.pyomo.lp
# Objective sense      : Minimize
# Variables            :  118751  [Nneg: 57001,  Box: 57000,  Binary: 4750]
# Objective nonzeros   :  105897
# Linear constraints   :   61908  [Less: 4750,  Greater: 32,  Equal: 57126]
#   Nonzeros           : 1473001
#   RHS nonzeros       :   58055
#
# Variables            : Min LB: 0.000000         Max UB: 120.0000
# Objective nonzeros   : Min   : 0.002222222      Max   : 1000.000
# Linear constraints   :
#   Nonzeros           : Min   : 1.000000         Max   : 207.9988
#   RHS nonzeros       : Min   : 1.000000         Max   : 6000.000
# CPLEX> Version identifier: 20.1.0.0 | 2020-11-10 | 9bedb6d68
# CPXPARAM_TimeLimit                               1800
# Tried aggregator 2 times.
# MIP Presolve eliminated 14875 rows and 24102 columns.
# Aggregator did 6 substitutions.
# Reduced MIP has 47027 rows, 94643 columns, and 1246665 nonzeros.
# Reduced MIP has 891 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 0.99 sec. (566.26 ticks)
# Probing time = 0.33 sec. (48.51 ticks)
# Cover probing fixed 0 vars, tightened 27185 bounds.
# Tried aggregator 1 time.
# Detecting symmetries...
# Reduced MIP has 47027 rows, 94643 columns, and 1246665 nonzeros.
# Reduced MIP has 891 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 1.70 sec. (646.64 ticks)
# Probing time = 0.31 sec. (46.25 ticks)
# Clique table members: 119.
# MIP emphasis: balance optimality and feasibility.
# MIP search method: dynamic search.
# Parallel mode: deterministic, using up to 8 threads.
# Root relaxation solution time = 130.94 sec. (35065.21 ticks)
#
#         Nodes                                         Cuts/
#    Node  Left     Objective  IInf  Best Integer    Best Bound    ItCnt     Gap
#
# *     0+    0                
#    1065   979    34555.5051   104    34911.2744    29382.4108  1247304   15.84%
#    1115   980    29473.0550   263    34911.2744    29382.4108  1251993   15.84%
#    1151  1044    30974.4264   213    34911.2744    29383.7597  1316528   15.83%
#    1186  1104    30937.4678   207    34911.2744    29383.7597  1387358   15.83%
#    1214  1083    32209.8260   155    34911.2744    29383.7597  1356455   15.83%
# *  1258+ 1092                        34896.4309    29383.7597            15.80%
#    1260  1156    32930.5387   146    34896.4309    29383.7597  1436540   15.80%
# *  1270+ 1092                        34895.5573    29383.7597            15.80%
#    1297  1167    30271.1605   230    34895.5573    29383.7597  1452843   15.80%
#    1341  1170    33841.5074   130    34895.5573    29437.8388  1449413   15.64%
# Elapsed time = 1256.27 sec. (268622.36 ticks, tree = 393.95 MB, solutions = 8)
#    1406  1249    31918.1981   181    34895.5573    29437.8388  1538852   15.64%
#    1458  1297    34627.1499   111    34895.5573    29437.8388  1579409   15.64%
#    1509  1298    29663.6354   259    34895.5573    29437.8388  1583623   15.64%
#    1557  1395        cutoff          34895.5573    29437.8388  1664279   15.64%
#    1617  1480    34812.7142    98    34895.5573    29437.8388  1754625   15.64%
#    1671  1522    30253.2609   242    34895.5573    29437.8388  1793426   15.64%
#    1702  1501    29751.2444   259    34895.5573    29437.8388  1782770   15.64%
#    1722  1534    30670.4686   227    34895.5573    29437.8388  1802076   15.64%
#
# Performing restart 1
#
# Repeating presolve.
# Tried aggregator 1 time.
# Reduced MIP has 47027 rows, 94643 columns, and 1246665 nonzeros.
# Reduced MIP has 891 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 24.94 sec. (7178.62 ticks)
# Tried aggregator 1 time.
# Reduced MIP has 47027 rows, 94643 columns, and 1246665 nonzeros.
# Reduced MIP has 891 binaries, 0 generals, 0 SOSs, and 0 indicators.
# Presolve time = 25.53 sec. (7378.37 ticks)
# Represolve time = 53.09 sec. (15117.84 ticks)
# *  1723+    0                        34894.0115    29437.8388            15.64%
#    1723     0    29309.1881   268    34894.0115     Cuts: 125  1985953   15.64%
#    1723     0    29312.7186   269    34894.0115      Cuts: 88  1986574   15.64%
#    1723     0    29316.0983   262    34894.0115     Cuts: 115  1987632   15.64%
#    1723     0    29334.2810   261    34894.0115     Cuts: 129  1989489   15.64%
#    1723     0    29339.9758   265    34894.0115     Cuts: 154  1990878   15.64%
#    1723     0    29344.6527   263    34894.0115     Cuts: 122  1992068   15.64%
# Advanced basis not built.
#
# Cover cuts applied:  59
# Flow cuts applied:  299
# Mixed integer rounding cuts applied:  728
# Lift and project cuts applied:  109
# Gomory fractional cuts applied:  2
#
# Root node processing (before b&c):
#   Real time             =  285.58 sec. (122516.55 ticks)
# Parallel b&c, 8 threads:
#   Real time             = 1514.63 sec. (352036.49 ticks)
#   Sync time (average)   =  134.73 sec.
#   Wait time (average)   =    0.00 sec.
#                           ------------
# Total (root+branch&cut) = 1800.20 sec. (474553.04 ticks)
#
# Solution pool: 9 solutions saved.
#
# MIP - Time limit exceeded, integer feasible:  Objective =  3.4894011519e+04
# Current MIP best bound =  2.9437838776e+04 (gap = 5456.17, 15.64%)
# Solution time = 1800.22 sec.  Iterations = 1992068  Nodes = 1723 (1)
# Deterministic time = 474553.38 ticks  (263.61 ticks/sec)
# CPLEX> Incumbent solution written to file 'C:\Users\91824\AppData\Local\Temp\tmph5o2w9u5.cplex.sol'.
# CPLEX>   Solver status : ok
#   Solver Termination condition : maxTimeLimit
